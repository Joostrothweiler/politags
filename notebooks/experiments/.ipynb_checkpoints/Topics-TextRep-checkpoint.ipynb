# %%
import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.multiclass import OneVsOneClassifier

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier

from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import train_test_split

from sklearn.model_selection import learning_curve
from sklearn.metrics import accuracy_score
from sklearn import metrics

# %%
corpus = []
labels = []
urls = []
files = [
    'kamerstukken_topics-multi_20160602_20161201.json',
    'kamerstukken_topics-multi_20160101_20160601.json',
    'kamerstukken_topics-multi_20170101_20170301.json',
    'kamerstukken_topics-multi_20170302_20170601.json',
    'kamerstukken_topics-multi_20170602_20180101.json',
    'kamerstukken_topics-multi_20180101_20180401.json'
]

for file in files:
    data = json.load(open('../../data_resources/topics/kamerstukken/{}'.format(file)))
    for obj in data:
        if len(obj['categories']) > 0 and 'Antwoord van' not in obj['content']:
            urls.append(obj['url'])
            corpus.append(obj['content'])
            labels.append(obj['categories'])



print(len(corpus))
print(len(labels))
# Out:
# 6976
# 6976

# %%
transformer = TfidfVectorizer(smooth_idf=False, min_df=0.001, max_df=0.08, sublinear_tf=True, ngram_range=(1,1))

# %%
X = transformer.fit_transform(corpus)
mlb = MultiLabelBinarizer()
y = mlb.fit_transform(labels)

# %%
clf = SGDClassifier(loss='log', penalty='none', alpha=1e-6, random_state=42, max_iter=10)
clf = OneVsRestClassifier(clf).fit(X, y)

def print_top10(vectorizer, clf, class_labels):
    """Prints features with the highest coefficient values, per class"""
    feature_names = vectorizer.get_feature_names()
    for i, class_label in enumerate(class_labels):
        top10 = np.argsort(clf.coef_[i])[-10:]
        print("%s: \n%s" % (class_label, "\n".join(feature_names[j] for j in top10)))

# %%
print_top10(transformer, clf, labels)
# Out:
# ['Onderwijs en wetenschap | Hoger onderwijs', 'Werk | Werkgelegenheid']:
# sint
# antillen
# services
# voorbij
# raffinaderij
# bosman
# curaçao
# aruba
# eustatius
# bonaire
# ['Natuur en milieu | Stoffen']:
# decentralisaties
# binnenlandsbestuur
# verhoudingen
# milieuzones
# overheden
# omroepgelderland
# vng
# brp
# accountants
# gemeentelijke
# ['Economie | Overige economische sectoren']:
# duurder
# gouden
# staatshoofd
# zei
# koning
# degene
# onderhoud
# bende
# oranjes
# oranje
# ['Recht | Strafrecht']:
# eerlijke
# corruptie
# stroomstoring
# verkiezingen
# ministeries
# berg
# politici
# stuit
# teeven
# israel
# ['Recht | Staatsrecht', 'Recht | Strafrecht']:
# noodgedwongen
# baan
# kant
# referendum
# ondernemers
# dure
# giftige
# rechtszaal
# familielid
# 50
# ['Natuur en milieu | Energie', 'Huisvesting | Organisatie en beleid']:
# ambtenaren
# limburgse
# cybersecurity
# provincies
# moderne
# wethouder
# rotterdams
# brabantse
# geïntimideerd
# burgemeesters
# ['Natuur en milieu | Organisatie en beleid']:
# aardbevingen
# gaf
# bzk
# sollicitatieprocedure
# hachchi
# moderne
# datum
# tongeren
# tonnen
# omroepgelderland
# ['Economie | Ondernemen']:
# mer
# persoon
# waterkwaliteit
# sloten
# cybersecurity
# moderne
# gehele
# rotterdams
# waterschappen
# waterschap
# ['Onderwijs en wetenschap | Voortgezet onderwijs']:
# vondsten
# bezuinigen
# rustig
# museum
# musea
# piet
# zwarte
# meenen
# erfgoed
# geschiedenis
# ['Economie | Organisatie en beleid']:
# degenen
# geschiedenis
# johan
# twitter
# koopmans
# band
# bezuinigen
# sluis
# manager
# bevel
# ['Zorg en gezondheid | Organisatie en beleid']:
# kro
# kranten
# omroep
# vice
# tv
# omroepen
# verliezen
# televisie
# journalisten
# npo
# ['Zorg en gezondheid | Organisatie en beleid']:
# uitzendingen
# rambam
# programma
# vara
# gedeeltelijke
# oneworld
# geschiedenis
# makers
# uitgezonden
# feestdagen
# ['Natuur en milieu | Bodem', 'Natuur en milieu | Energie']:
# permanente
# verblijfplaats
# zundert
# strijdig
# ijsselmeer
# vakantieparken
# arbeidsmigranten
# horeca
# campings
# camping
# ['Zorg en gezondheid | Organisatie en beleid']:
# haat
# islam
# christenen
# diyanet
# enschede
# godsdienstvrijheid
# salafisten
# religieuze
# moskeeën
# imam
# ['Bestuur | Gemeenten']:
# sportverenigingen
# sportaccommodaties
# veiliger
# knvb
# sportclubs
# matchfixing
# sportevenementen
# voetballers
# sporters
# dekken
# ['Openbare orde en veiligheid | Terrorisme']:
# stedelijke
# behandelde
# medeoverheden
# nieuwbouw
# lakse
# faalt
# dodelijke
# bouw
# experimenten
# ronnes
# ['Recht | Strafrecht']:
# israëlische
# bouali
# myanmar
# producten
# ontwikkelingssamenwerking
# lokale
# handel
# heffingen
# trade
# ttip
# ['Huisvesting | Huren en verhuren']:
# facebook
# overheidsdiensten
# telecommunicatiewet
# kwetsbaarheden
# concurrent
# klaar
# internet
# uitrol
# digitale
# ict
# ['Recht | Burgerlijk recht', 'Landbouw | Organisatie en beleid']:
# dagen
# san
# giftige
# olieraffinaderij
# verlies
# tabaksindustrie
# pfoa
# ulenbelt
# deal
# dupont
# ['Ruimte en infrastructuur | Netwerken']:
# wetgeving
# ziggo
# radar
# hijink
# winstuitkering
# aandeelhouders
# gesjoemel
# oneerlijke
# dure
# boete
# ['Migratie en integratie | Immigratie']:
# faillissement
# lonen
# akzonobel
# traag
# berg
# investeerder
# mkb
# financiering
# ppg
# opdrachtgevers
# ['Onderwijs en wetenschap | Beroepsonderwijs']:
# externe
# ets
# registratie
# schijnzelfstandigheid
# keurmerk
# loopt
# bedrijfsleven
# bepalingen
# consumenten
# supermarkten
# ['Internationaal | Organisatie en beleid']:
# horeca
# european
# visserijsector
# huizenkopers
# vermeij
# mijnbouwschade
# vis
# postnl
# accountants
# banken
# ['Migratie en integratie | Tijdelijk verblijf']:
# planten
# gevestigd
# diersoorten
# wijziging
# belastingheffing
# vliet
# bemiddelaars
# huurhuizen
# key
# toeristen
# ['Werk | Arbeidsomstandigheden']:
# schepen
# staatssteun
# interessant
# maatschappijen
# subsidiegelden
# kiwa
# aanvragen
# herkent
# engeland
# chauffeurs
# ['Huisvesting | Huren en verhuren']:
# beschikte
# tijdlijn
# doorbraak
# begroting
# korting
# gesprekken
# lichaam
# lening
# terugbetaald
# beloond
# ['Natuur en milieu | Water', 'Natuur en milieu | Stoffen']:
# heffing
# belastingverdrag
# dividendbelasting
# btw
# rulings
# belastingen
# belastingparadijzen
# ozb
# fiscale
# belastingdienst
# ['Verkeer | Weg']:
# centrale
# aflossen
# vaag
# kpmg
# tuchtrecht
# pag
# leidraad
# krediet
# kredieten
# afm
# ['Zorg en gezondheid | Organisatie en beleid']:
# zoveel
# minima
# topsalarissen
# koopkracht
# salaris
# 111
# bruto
# wnt
# inkomens
# delta
# ['Internationaal | Organisatie en beleid']:
# accountant
# uts
# stabiliteit
# rooijen
# spaargeld
# beleggingen
# services
# kansspelautoriteit
# rabobank
# kansspelen
# ['Recht | Rechtspraak']:
# vergunningverlening
# sloop
# npr
# bouwbesluit
# woningbouw
# versterkt
# aangelegd
# arnhem
# woningen
# aardbevingsbestendig
# ['Financiën | Belasting', 'Werk | Arbeidsvoorwaarden']:
# verhuurder
# middeninkomens
# corporaties
# betaalbare
# huurwoning
# koerhuis
# verhuren
# huurprijs
# huurders
# huurwoningen
# ['Zorg en gezondheid | Organisatie en beleid']:
# senioren
# aankoop
# waard
# bouwkundige
# huizen
# starters
# huis
# keuring
# hypotheek
# huizenkopers
# ['Internationaal | Organisatie en beleid']:
# aardgas
# vakantieparken
# eijs
# gasaansluiting
# wonen
# hypotheekverstrekkers
# energielabel
# ronnes
# correctie
# woningmarkt
# ['Recht | Strafrecht', 'Zorg en gezondheid | Jongeren']:
# kazerne
# militairen
# zeggen
# wereldwijde
# massale
# korea
# kernwapens
# luchtmacht
# veteranen
# defensie
# ['Internationaal | Organisatie en beleid', 'Openbare orde en veiligheid | Staatsveiligheid', 'Openbare orde en veiligheid | Terrorisme']:
# vluchtelingenkinderen
# parlement
# hervormingen
# plannen
# verhoeven
# vertellen
# way
# griekse
# eu
# commissie
# ['Verkeer | Water']:
# hevige
# zwitserse
# sancties
# diks
# schending
# ak
# activist
# ceta
# report
# haalt
# ['Verkeer | Water']:
# missie
# use
# ambtsbericht
# materieel
# dreigement
# witte
# white
# afghanistan
# koerden
# karabulut
# ['Openbare orde en veiligheid | Staatsveiligheid', 'Economie | ICT']:
# donoren
# ethiopië
# versneld
# ontwikkelingslanden
# venture
# noodhulp
# handel
# kenia
# dollar
# ontwikkelingssamenwerking
# ['Natuur en milieu | Bodem', 'Natuur en milieu | Water']:
# their
# autoriteiten
# gesprek
# activists
# servaes
# minderheden
# ambassades
# rusland
# sjoerdsma
# bommel
# ['Zorg en gezondheid | Organisatie en beleid']:
# reisadvies
# association
# korea
# weigert
# zeven
# gearresteerd
# bulgaarse
# reis
# congres
# klaver
# ['Verkeer | Organisatie en beleid']:
# predicaat
# uitbraak
# geslacht
# gelderland
# vlees
# dierenhandel
# staatsbosbeheer
# dier
# pluimveehouders
# dieren
# ['Natuur en milieu | Afval']:
# landbouw
# dijk
# mestbeleid
# mest
# landbouwgrond
# tuinbouw
# boeren
# glyfosaat
# landbouwers
# professionalisering
# ['Recht | Burgerlijk recht']:
# toezien
# middel
# biologische
# ontwerpbesluit
# xtc
# voedselproductie
# kankerverwekkend
# gewasbeschermingsmiddelen
# resten
# planten
# ['Openbare orde en veiligheid | Criminaliteit']:
# voedselveiligheid
# varianten
# ontheffing
# foodwatch
# duurzaamheid
# voedselproductie
# insecten
# giftige
# fipronil
# eieren
# ['Openbare orde en veiligheid | Criminaliteit', 'Recht | Strafrecht']:
# uitzetting
# veilig
# gedetineerd
# begeleiden
# ambtsbericht
# terugkeer
# hoopt
# genoeg
# vrijwillige
# iom
# ['Natuur en milieu | Natuur- en landschapsbeheer', 'Economie | Handel']:
# vluchtelingen
# groepen
# asielzoekerscentrum
# coa
# gesthuizen
# transportsector
# syrische
# vreemdelingen
# ind
# asielzoekers
# ['Openbare orde en veiligheid | Organisatie en beleid', 'Openbare orde en veiligheid | Rampen']:
# misdaden
# samenleving
# kwijtschelding
# voetballers
# huwelijken
# verblijfsvergunningen
# integratiebeleid
# geaardheid
# inburgering
# integratie
# ['Internationaal | Ontwikkelingssamenwerking']:
# amsterdamse
# gestuurd
# syriërs
# onbewust
# géén
# nederlander
# ombudsman
# armeense
# armenië
# nederlanderschap
# ['Zorg en gezondheid | Verzekeringen']:
# dijkhoff
# onhoudbaar
# gelet
# vreemdeling
# servaes
# douane
# unhcr
# afgewezen
# eritrese
# protest
# ['Natuur en milieu | Organisatie en beleid']:
# personen
# afghaanse
# gezondheidsklachten
# ervaringen
# asielzoekerscentra
# harderwijk
# woont
# dakloze
# onderzoekscommissie
# terugkeren
# ['Ruimte en infrastructuur | Organisatie en beleid', 'Verkeer | Weg']:
# visserij
# stille
# aziatische
# zuivering
# opruimen
# verhalen
# recycling
# inzameling
# afvalwater
# afval
# ['Natuur en milieu | Stoffen']:
# groningse
# sterkste
# jannie
# vervuilde
# beckerman
# bodem
# waard
# aardbevingen
# grondwater
# bevingen
# ['Zorg en gezondheid | Organisatie en beleid']:
# milieubeheer
# gas
# gasveld
# sterkste
# energieakkoord
# windturbines
# contra
# rtvnoord
# windmolens
# energie
# ['Bestuur | Organisatie en beleid']:
# dichtbij
# luchthaven
# 984
# moderne
# klacht
# urgente
# vliegtuigen
# geluidshinder
# geluidsschermen
# geluidsoverlast
# ['Recht | Strafrecht']:
# tno
# 2020
# decorrespondent
# vies
# emissies
# automobilisten
# ce
# luchtvervuiling
# co2
# luchtkwaliteit
# ['Sociale zekerheid | Jongeren']:
# dierenbescherming
# landschap
# leenders
# bouwen
# dierenleed
# duinen
# bomen
# ecologische
# paarden
# bos
# ['Landbouw | Dieren']:
# raan
# gewasbeschermingsmiddelen
# kustpact
# steden
# gebouwen
# greenpeace
# klimaatbeleid
# staten
# geurts
# sde
# ['Recht | Staatsrecht', 'Economie | Handel']:
# uitstoot
# overschrijdingen
# giftige
# stoffen
# nucleaire
# blootgesteld
# asbestdaken
# stof
# kankerverwekkend
# asbest
# ['Openbare orde en veiligheid | Staatsveiligheid', 'Economie | ICT']:
# afvalwater
# waterzuivering
# bron
# eindrapport
# ziengs
# vervuiling
# grondwater
# drinkwater
# zuivering
# noordzee
# ['Financiën | Inkomensbeleid']:
# aboutaleb
# 23
# klassen
# ouderbijdrage
# school
# primair
# basisschool
# vertrouwen
# basisonderwijs
# basisscholen
# ['Zorg en gezondheid | Organisatie en beleid']:
# westerse
# college
# volwassen
# lucas
# roc
# beroepsonderwijs
# vmbo
# graaf
# stage
# mbo
# ['Zorg en gezondheid | Ethiek']:
# besteding
# hoger
# tu
# leenstelsel
# universiteit
# scienceguide
# medezeggenschap
# rijksuniversiteit
# hoogleraren
# uva
# ['Zorg en gezondheid | Jongeren', 'Openbare orde en veiligheid | Organisatie en beleid']:
# wisten
# veen
# tu
# delft
# vondsten
# universiteiten
# piadijkstra
# contour
# schadegevallen
# wetenschappelijke
# ['Bestuur | Gemeenten', 'Openbare orde en veiligheid | Organisatie en beleid', 'Economie | ICT']:
# hul
# grashoff
# namelijk
# stichting
# experiment
# beertema
# leerkrachten
# wetenschap
# cultuur
# scholen
# ['Recht | Strafrecht']:
# lezen
# siderius
# illegaal
# marktwerking
# taal
# becker
# onderwijsinspectie
# passend
# samenwerkingsverband
# speciaal
# ['Onderwijs en wetenschap | Beroepsonderwijs']:
# toets
# vernieuwde
# profielen
# advies
# vakken
# vwo
# vmbo
# middelbare
# schoolbestuur
# voortgezet
# ['Huisvesting | Kopen en verkopen']:
# verkopers
# overval
# gebeurt
# gebeuren
# fraude
# matchfixing
# diefstal
# markuszower
# criminelen
# criminele
# ['Cultuur en recreatie | Religie', 'Openbare orde en veiligheid | Organisatie en beleid']:
# datalek
# persoon
# dood
# ede
# gevangenissen
# geweldsincidenten
# nasleep
# teams
# kraken
# coffeeshop
# ['Cultuur en recreatie | Media']:
# noodkreet
# veiligheidsregio
# bellen
# agenten
# brandweer
# politieagenten
# politiebond
# agent
# brand
# politie
# ['Migratie en integratie | Immigratie']:
# straal
# emmen
# case
# delfzijl
# voorbereid
# deugt
# limburger
# reddingsbrigade
# onzeker
# kernramp
# ['Zorg en gezondheid | Organisatie en beleid', 'Financiën | Inkomensbeleid']:
# beheerders
# bewaken
# bewindspersonen
# spionage
# uitsluiten
# inlichtingendiensten
# turkse
# mailadres
# veiligheidsdiensten
# inlichtingendienst
# ['Openbare orde en veiligheid | Politie, brandweer en hulpdiensten']:
# aanslagen
# platform
# radicalisering
# terreurverdachte
# terugkeerders
# terreur
# paspoort
# jihadisten
# terrorisme
# terroristen
# ['Zorg en gezondheid | Organisatie en beleid']:
# voorop
# psychologische
# buitenproportionele
# hield
# wijzigingen
# aanhoudingen
# state
# bannen
# topambtenaar
# jongen
# ['Openbare orde en veiligheid | Politie, brandweer en hulpdiensten', 'Werk | Arbeidsvoorwaarden']:
# begrotingsbehandeling
# halt
# misdragen
# gedrag
# wob
# leidinggevende
# bezwaar
# demonstraties
# kindermishandeling
# telefonisch
# ['Economie | Overige economische sectoren', 'Recht | Burgerlijk recht', 'Huisvesting | Huren en verhuren']:
# complexe
# bewindvoerders
# bergkamp
# hiertoe
# consumentenbond
# schade
# aardbevingsschade
# faillissement
# burgers
# contra
# ['Financiën | Financieel toezicht']:
# kampt
# laag
# wob
# krakers
# regeerakkoord
# rechters
# gesubsidieerde
# 2012
# onderbouwen
# rechtsbijstand
# ['Economie | Ondernemen', 'Financiën | Belasting']:
# rechtszaal
# raadsleden
# poch
# vrijuit
# strafhof
# deurwaarder
# schuldeisers
# rechter
# rechtbanken
# rechtspraak
# ['Bestuur | Gemeenten']:
# godsdienstvrijheid
# subsidies
# erdogan
# grootschalig
# mensenrechtenschendingen
# privacy
# antisemitisme
# gezet
# referendum
# discriminatie
# ['Economie | ICT', 'Internationaal | Internationale samenwerking']:
# strafvervolging
# wegens
# strafrechtelijke
# ernstig
# strafbaar
# openbaar
# drugsgebruik
# straffen
# strafrecht
# doodstraf
# ['Openbare orde en veiligheid | Terrorisme', 'Openbare orde en veiligheid | Criminaliteit']:
# inlichtingendiensten
# formeel
# snellere
# tennet
# heffen
# mobiel
# kv
# mobiele
# uitrol
# bereik
# ['Internationaal | Organisatie en beleid']:
# hoogland
# 2050
# file
# monumenten
# plannen
# provincies
# transport
# opgelost
# tunnels
# bruggen
# ['Zorg en gezondheid | Ziekten en behandelingen', 'Zorg en gezondheid | Ethiek']:
# von
# ehrm
# martels
# westerschelde
# gesloopt
# besproken
# leegstand
# detailhandel
# sluis
# muur
# ['Verkeer | Spoor']:
# rijkswaterstaat
# zand
# beveiligd
# binnenlands
# kapotte
# waterstaat
# waterschap
# rws
# waterschappen
# sluizen
# ['Openbare orde en veiligheid | Organisatie en beleid', 'Sociale zekerheid | Ouderen', 'Verkeer | Weg']:
# yücel
# roma
# aboutaleb
# gezinnen
# toenemend
# armoede
# kinderbijslag
# siderius
# kinderopvang
# kinderopvangtoeslag
# ['Internationaal | Ontwikkelingssamenwerking']:
# uitkering
# vrijwilligerswerk
# wacht
# jeugdhulp
# westerveld
# verdwijnt
# vennootschapsbelasting
# geef
# baan
# jongeren
# ['Zorg en gezondheid | Organisatie en beleid']:
# rechtszaken
# herinneren
# degene
# pensioenfonds
# abp
# regeling
# nabestaandenpensioen
# compensatie
# opdraait
# mantelzorger
# ['Recht | Rechtspraak']:
# uwv
# bijstandsuitkering
# participatiewet
# bijstand
# wajong
# aanvraag
# armoede
# bijstandsgerechtigden
# uitkeringen
# schuldhulpverlening
# ['Economie | Transport']:
# vo
# compensatie
# ecb
# ontslag
# blijven
# dupe
# deelnemers
# manifest
# pensioenfondsen
# abp
# ['Zorg en gezondheid | Organisatie en beleid']:
# uitkeringen
# fraude
# gedaald
# onterecht
# ww
# werkloosheid
# jongeren
# gekort
# meegerekend
# geef
# ['Zorg en gezondheid | Organisatie en beleid']:
# centrale
# dagbesteding
# crvb
# achteruit
# verzekerde
# politieagenten
# gehandicapte
# netto
# ziekteverzuim
# voorspeld
# ['Openbare orde en veiligheid | Politie, brandweer en hulpdiensten']:
# luchtruim
# drones
# icao
# luchtvaartmaatschappijen
# vliegtuigen
# schiphol
# luchtvaart
# visser
# piloten
# luchthaven
# ['Financiën | Belasting', 'Bestuur | Koninklijk Huis']:
# openbaar
# ov
# reizigers
# inzet
# america
# smaling
# veteranen
# helvert
# transport
# rijbewijs
# ['Openbare orde en veiligheid | Organisatie en beleid', 'Financiën | Belasting', 'Recht | Staatsrecht']:
# translink
# derde
# traject
# station
# bureaucratie
# trein
# intercity
# spoor
# prorail
# ns
# ['Landbouw | Dieren']:
# plicht
# hulpverlening
# concessie
# schepen
# havens
# certificaat
# beerput
# zeeschepen
# jacobi
# binnenvaart
# ["Zorg en gezondheid | Gezondheidsrisico's", 'Economie | Overige economische sectoren']:
# langs
# tln
# hoogland
# ongelukken
# automobilisten
# vrachtverkeer
# snelwegen
# verkeersveiligheid
# tolheffing
# vrachtwagens
# ['Economie | Bouwnijverheid']:
# pesten
# özdil
# beveiligers
# arbeidsmigranten
# gezet
# kinderarbeid
# schoolbestuur
# misstanden
# dupont
# arbeidsomstandigheden
# ['Zorg en gezondheid | Verzekeringen', 'Zorg en gezondheid | Organisatie en beleid']:
# next
# rechten
# uitbreiding
# werk
# lager
# compensatieregeling
# uitbuiting
# wiersma
# cao
# uitgebuit
# ['Landbouw | Planten']:
# afwijkt
# aandeel
# verhoging
# arbeidsinkomensquote
# 1995
# zware
# kleiner
# verdubbeling
# beroepen
# verhogen
# ['Verkeer | Luchtvaart', 'Economie | Transport']:
# dupe
# schrapt
# fnv
# doorstart
# bezuinigen
# ton
# vestiging
# hengelo
# hijink
# managers
# ['Zorg en gezondheid | Organisatie en beleid', 'Zorg en gezondheid | Ethiek']:
# beschouwd
# discrimineren
# verdienen
# opportuun
# open
# scp
# onderstaande
# vervallen
# opdrachten
# dienst
# ['Natuur en milieu | Natuur- en landschapsbeheer', 'Natuur en milieu | Organisatie en beleid']:
# kant
# vluchteling
# werkgevers
# verdringing
# arbeidsmarkt
# baan
# werkzoekenden
# 50
# kerstens
# contracten
# ['Sociale zekerheid | Organisatie en beleid', 'Financiën | Organisatie en beleid', 'Financiën | Inkomensbeleid']:
# donoren
# tuchtrecht
# nabestaanden
# hoort
# medisch
# nieuwsuur
# wisten
# coöperatie
# reclame
# euthanasie
# ['Werk | Arbeidsomstandigheden', 'Natuur en milieu | Stoffen']:
# afhankelijk
# adhd
# antibiotica
# geneesmiddel
# voortman
# hulpmiddelen
# medicatie
# geneesmiddelen
# medicijnen
# apothekers
# ['Financiën | Inkomensbeleid']:
# drug
# proeven
# koorts
# besmet
# complicaties
# kankerverwekkende
# tabaksindustrie
# kuik
# stoffen
# gezondheid
# ['Onderwijs en wetenschap | Hoger onderwijs', 'Huisvesting | Huren en verhuren']:
# meisjes
# aanbeveling
# stelselverantwoordelijke
# jongeren
# kritiek
# meldcode
# volp
# kindermishandeling
# kinderen
# jeugd
# ['Onderwijs en wetenschap | Hoger onderwijs']:
# alfahulpen
# nza
# farmaceutische
# zorgsector
# ziekenhuis
# mantelzorgers
# zorgvisie
# kuik
# wmo
# pgb
# ['Zorg en gezondheid | Organisatie en beleid', 'Financiën | Belasting']:
# heel
# bndestem
# hoogbejaarde
# beboet
# slapen
# vallende
# moeder
# bewoners
# verpleeghuis
# ouderen
# ['Natuur en milieu | Stoffen']:
# zorggeld
# kruis
# zilveren
# bont
# dure
# gerven
# gedeclareerd
# verzekerden
# vergoed
# zorgverzekeraars
# ['Economie | ICT', 'Zorg en gezondheid | Organisatie en beleid']:
# xtc
# resten
# gezonde
# kenniscentrum
# food
# cost
# gezond
# pak
# kritiek
# voeding
# ['Economie | Overige economische sectoren', 'Economie | Markttoezicht']:
# veertien
# jemen
# zieke
# overleden
# palliatieve
# complicaties
# abortus
# patiënten
# zorgaanbieder
# operaties
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-52-2853c4acb7ed> in <module>()
# ----> 1 print_top10(transformer, clf, labels)
#
# <ipython-input-51-f72f6e8aa23e> in print_top10(vectorizer, clf, class_labels)
#       6     feature_names = vectorizer.get_feature_names()
#       7     for i, class_label in enumerate(class_labels):
# ----> 8         top10 = np.argsort(clf.coef_[i])[-10:]
#       9         print("%s: \n%s" % (class_label, "\n".join(feature_names[j] for j in top10)))
#      10
#
# IndexError: index 111 is out of bounds for axis 0 with size 111

# %%
def top_tfidf_feats(row, features, top_n=25):
    ''' Get top n tfidf values in row and return them with their corresponding feature names.'''
    topn_ids = np.argsort(row)[::-1][:top_n]
    top_feats = [(features[i], row[i]) for i in topn_ids]
    df = pd.DataFrame(top_feats)
    df.columns = ['feature', 'tfidf']
    return df

top_tfidf_feats(corpus[0], transformer.get_feature_names()).head()
# Out:
#   feature tfidf
# 0      00     V

# %%
def top_feats_in_doc(Xtr, features, row_id, top_n=25):
    ''' Top tfidf features in specific document (matrix row) '''
    row = np.squeeze(Xtr[row_id].toarray())
    return top_tfidf_feats(row, features, top_n)

top_feats_in_doc(X, transformer.get_feature_names(), 0)
# Out:
#            feature     tfidf
# 0       promovendi  0.393832
# 1      aanstelling  0.227078
# 2         dubieuze  0.214006
# 3               li  0.204763
# 4       aangeboden  0.202382
# 5         parttime  0.184472
# 6       contracten  0.182082
# 7      persbericht  0.176459
# 8          netwerk  0.165654
# 9         contract  0.164176
# 10       ontduiken  0.164115
# 11     hogescholen  0.154562
# 12          krijgt  0.140287
# 13  universiteiten  0.139103
# 14       zekerheid  0.136566
# 15             vos  0.136224
# 16        kerstens  0.124358
# 17            norm  0.122937
# 18     nagestreefd  0.112174
# 19             288  0.110473
# 20    fatsoenlijke  0.102168
# 21         dubieus  0.101293
# 22       kwaliteit  0.097646
# 23        fulltime  0.097571
# 24           korte  0.097367

# %%
def top_mean_feats(Xtr, features, grp_ids=None, min_tfidf=0.1, top_n=25):
    ''' Return the top n features that on average are most important amongst documents in rows
        indentified by indices in grp_ids. '''
    if grp_ids:
        D = Xtr[grp_ids].toarray()
    else:
        D = Xtr.toarray()

    D[D < min_tfidf] = 0
    tfidf_means = np.mean(D, axis=0)
    return top_tfidf_feats(tfidf_means, features, top_n)

top_mean_feats(X, transformer.get_feature_names())
# Out:
#             feature     tfidf
# 0        mondelinge  0.012009
# 1          kinderen  0.005942
# 2           politie  0.005801
# 3                eu  0.004216
# 4          gemeente  0.003809
# 5            turkse  0.003806
# 6         bedrijven  0.003666
# 7         studenten  0.003561
# 8           scholen  0.003504
# 9            ouders  0.003446
# 10     asielzoekers  0.003441
# 11        telegraaf  0.003403
# 12          turkije  0.003387
# 13           bontes  0.003151
# 14  belastingdienst  0.003149
# 15        patiënten  0.003126
# 16         klaveren  0.003073
# 17         defensie  0.003050
# 18     ziekenhuizen  0.003006
# 19        rotterdam  0.002945
# 20         medische  0.002942
# 21               ad  0.002936
# 22             raad  0.002921
# 23          vrouwen  0.002917
# 24              nam  0.002899

# %%
def top_feats_by_class(Xtr, y, features, min_tfidf=0.1, top_n=25):
    ''' Return a list of dfs, where each df holds top_n features and their mean tfidf value
        calculated across documents with the same class label. '''
    dfs = []
    labels = np.unique(y)
    for label in labels:
        ids = []
        for i in range(0,len(y)):
            if y[i] == label:
                ids.append(i)
        
        feats_df = top_mean_feats(Xtr, features, ids, min_tfidf=min_tfidf, top_n=top_n)
        feats_df.label = label
        dfs.append(feats_df)
    return dfs


labels = []
a = mlb.inverse_transform(y)

for obj in a:
    labels.append(obj[0])

    
for df in top_feats_by_class(X, labels, transformer.get_feature_names()):
    print(df.label)
    print(df)
# Out:
# Bestuur | De Nederlandse Antillen en Aruba
#          feature     tfidf
# 0        curaçao  0.118381
# 1          aruba  0.097078
# 2         bosman  0.081530
# 3        bonaire  0.075072
# 4           sint  0.071322
# 5        maarten  0.065128
# 6   raffinaderij  0.047075
# 7         casino  0.027844
# 8      eustatius  0.027637
# 9     koninkrijk  0.026468
# 10       curacao  0.026278
# 11         citgo  0.025713
# 12     curaçaose  0.025130
# 13     venezuela  0.023854
# 14           uts  0.023765
# 15          neen  0.023489
# 16       aankoop  0.023355
# 17       lichaam  0.022858
# 18            st  0.022282
# 19           com  0.021377
# 20     begroting  0.021340
# 21      antillen  0.020325
# 22    gevangenis  0.020324
# 23    financieel  0.020034
# 24     caribisch  0.019433
# Bestuur | Gemeenten
#                feature     tfidf
# 0             gemeente  0.031321
# 1                  vng  0.023544
# 2        gemeentelijke  0.021580
# 3           raadsleden  0.020802
# 4                  brp  0.019755
# 5     persoonsgegevens  0.018846
# 6         burgemeester  0.016821
# 7           mondelinge  0.016808
# 8                 raak  0.015909
# 9              burgers  0.015647
# 10            raadslid  0.012798
# 11  binnenlandsbestuur  0.011806
# 12                 den  0.011731
# 13             privacy  0.011333
# 14           levenloos  0.011136
# 15                haag  0.010600
# 16         stembureaus  0.010449
# 17           oosenbrug  0.009952
# 18                  ad  0.009697
# 19         accountants  0.009669
# 20               fokke  0.009465
# 21          referendum  0.009429
# 22            bergkamp  0.009411
# 23              lokale  0.009135
# 24             geboren  0.008934
# Bestuur | Koninklijk Huis
#               feature     tfidf
# 0             oranjes  0.107570
# 1               bende  0.094346
# 2           onderhoud  0.092328
# 3              gouden  0.082722
# 4              koning  0.066796
# 5           president  0.057799
# 6          koninklijk  0.048699
# 7              bedrag  0.048135
# 8             bewaken  0.047044
# 9          beveiligen  0.046469
# 10            premium  0.045545
# 11             oranje  0.043191
# 12          reportage  0.039580
# 13      onafhankelijk  0.038736
# 14               fort  0.038526
# 15                000  0.037136
# 16        staatshoofd  0.034983
# 17             dienst  0.034063
# 18         mondelinge  0.033874
# 19              rutte  0.033476
# 20            begroot  0.033161
# 21               huis  0.032263
# 22          beveiligd  0.031853
# 23             tonnen  0.029629
# 24  onderzoeksrapport  0.029627
# Bestuur | Organisatie en beleid
#                     feature     tfidf
# 0                mondelinge  0.015031
# 1                      raak  0.012168
# 2               bestuurders  0.012068
# 3              verkiezingen  0.012068
# 4                 regeldruk  0.010908
# 5              aanbesteding  0.010539
# 6               ministeries  0.010154
# 7               topinkomens  0.010114
# 8                  publieke  0.009032
# 9             beleidsregels  0.008945
# 10                president  0.008913
# 11                corruptie  0.008559
# 12  volksvertegenwoordigers  0.008220
# 13                parlement  0.008066
# 14                normering  0.007900
# 15                    actal  0.007760
# 16            stroomstoring  0.007603
# 17             bestuurlijke  0.007356
# 18               ambtenaren  0.007319
# 19                rtlnieuws  0.007003
# 20                    stuit  0.006840
# 21                bedrijven  0.006554
# 22                      npo  0.006550
# 23                 politiek  0.006474
# 24                 algemene  0.006430
# Bestuur | Parlement
#             feature     tfidf
# 0        mondelinge  0.037646
# 1       ondernemers  0.023254
# 2            schade  0.018966
# 3            jannie  0.017907
# 4      ondermijning  0.017831
# 5          avrotros  0.016605
# 6            kuiken  0.016258
# 7              zand  0.016236
# 8        eenvandaag  0.015476
# 9   zorgmedewerkers  0.015389
# 10    noodgedwongen  0.013666
# 11       familielid  0.013481
# 12          hackers  0.013205
# 13       referendum  0.013148
# 14             baan  0.012829
# 15           things  0.012610
# 16        telegraaf  0.012548
# 17       indicaties  0.012475
# 18             lege  0.012353
# 19             kant  0.012092
# 20        ontslagen  0.012035
# 21        verhoeven  0.011911
# 22         rekening  0.011653
# 23       documenten  0.011524
# 24         eritrese  0.011425
# Bestuur | Provincies
#           feature     tfidf
# 0   burgemeesters  0.182677
# 1   geïntimideerd  0.144489
# 2       brabantse  0.135378
# 3       wethouder  0.117357
# 4      ambtenaren  0.113783
# 5         drenthe  0.111828
# 6            slot  0.109920
# 7       limburgse  0.109201
# 8       benoeming  0.096267
# 9          bruins  0.096244
# 10      regionaal  0.090222
# 11    integriteit  0.090150
# 12          vaker  0.088535
# 13      omstreden  0.086211
# 14   gezamenlijke  0.085117
# 15            nrc  0.083268
# 16     mondelinge  0.083015
# 17     provincies  0.079020
# 18     initiatief  0.078425
# 19            zet  0.076296
# 20      googleamp  0.072029
# 21     handvatten  0.070813
# 22     gouverneur  0.068779
# 23            coc  0.067966
# 24         niveau  0.066810
# Bestuur | Rijksoverheid
#                   feature     tfidf
# 0                defensie  0.038303
# 1              ambtenaren  0.031167
# 2                  tonnen  0.026057
# 3                  pesten  0.025129
# 4                     ceo  0.025067
# 5                  caluwé  0.023734
# 6                schiphol  0.023631
# 7          vertrouwelijke  0.023398
# 8                  straks  0.022252
# 9               werkvloer  0.022148
# 10                    aow  0.021772
# 11                 deelde  0.021256
# 12              benoeming  0.020943
# 13                proeven  0.019702
# 14                    bzk  0.019483
# 15           aardbevingen  0.019425
# 16           werkomgeving  0.018842
# 17               tongeren  0.018660
# 18        rijkswaterstaat  0.018357
# 19        belastingdienst  0.018263
# 20              professor  0.017208
# 21  sollicitatieprocedure  0.016623
# 22               subsidie  0.016438
# 23                 staats  0.015241
# 24                collega  0.015059
# Bestuur | Waterschappen
#                feature     tfidf
# 0        waterschappen  0.202462
# 1           waterschap  0.120853
# 2                  wnt  0.094966
# 3      vertrekregeling  0.089613
# 4            sectorale  0.070263
# 5            uitkering  0.069361
# 6          componenten  0.065471
# 7          voorschrift  0.064760
# 8          beëindiging  0.063488
# 9               sloten  0.061507
# 10          betrokkene  0.060647
# 11       dienstverband  0.060497
# 12       beleidsregels  0.059688
# 13                  ww  0.059310
# 14      overeengekomen  0.058263
# 15         uitkeringen  0.055956
# 16         bezoldiging  0.055198
# 17      waterkwaliteit  0.053108
# 18                 cao  0.052553
# 19  arbeidsvoorwaarden  0.051778
# 20               water  0.044856
# 21   ontslagvergoeding  0.043139
# 22          huishouden  0.039103
# 23             persoon  0.038747
# 24           afkoopsom  0.037814
# Cultuur en recreatie | Cultuur
#          feature     tfidf
# 0        erfgoed  0.076706
# 1           piet  0.044963
# 2         zwarte  0.039927
# 3   geschiedenis  0.038813
# 4        cultuur  0.031671
# 5     monumenten  0.028865
# 6      telegraaf  0.025304
# 7           muur  0.024731
# 8     geselschap  0.023660
# 9     mondelinge  0.023049
# 10      subsidie  0.022929
# 11        behoud  0.022580
# 12   evenementen  0.022209
# 13          laan  0.022046
# 14     culturele  0.022042
# 15     cultureel  0.021734
# 16          onze  0.020599
# 17        meenen  0.020466
# 18         kwint  0.019788
# 19     eigenaren  0.018417
# 20         musea  0.017681
# 21         fonds  0.017377
# 22        resten  0.016845
# 23        museum  0.016445
# 24       minuten  0.016259
# Cultuur en recreatie | Kunst
#          feature     tfidf
# 0          sluis  0.082011
# 1       subsidie  0.080659
# 2         museum  0.069965
# 3        manager  0.067690
# 4          meent  0.066912
# 5     oprichting  0.065613
# 6        degenen  0.062321
# 7          bevel  0.055529
# 8   gerechtelijk  0.055529
# 9           band  0.054489
# 10    initiatief  0.054113
# 11         krant  0.050534
# 12       erfgoed  0.049066
# 13         musea  0.047486
# 14      koopmans  0.046873
# 15     stichting  0.045914
# 16         raden  0.043757
# 17     heimelijk  0.043132
# 18         ophef  0.042783
# 19       erdogan  0.041047
# 20       familie  0.040359
# 21           gek  0.040076
# 22      bevingen  0.039401
# 23       twitter  0.039254
# 24        martin  0.038800
# Cultuur en recreatie | Media
#            feature     tfidf
# 0              npo  0.063419
# 1     journalisten  0.045560
# 2           omroep  0.045420
# 3         publieke  0.039049
# 4        programma  0.027351
# 5         mediawet  0.025673
# 6       journalist  0.022525
# 7        televisie  0.021756
# 8            media  0.020778
# 9               tv  0.019750
# 10   journalistiek  0.017672
# 11          bontes  0.015546
# 12            homo  0.015382
# 13  journalistieke  0.014830
# 14         cultuur  0.014819
# 15        omroepen  0.014652
# 16             azc  0.014506
# 17      uitzending  0.014151
# 18          powned  0.013879
# 19        klaveren  0.013063
# 20      wetenschap  0.012932
# 21       geenstijl  0.012816
# 22         vrouwen  0.012026
# 23        internet  0.011882
# 24             kro  0.011807
# Cultuur en recreatie | Organisatie en beleid
#                 feature     tfidf
# 0          schoonmakers  0.117211
# 1                rambam  0.106856
# 2                hotels  0.077521
# 3                   szw  0.063363
# 4               vermeij  0.061758
# 5             uitgebuit  0.052967
# 6             weyenberg  0.052081
# 7                 zwaar  0.049670
# 8             controles  0.049305
# 9            misstanden  0.046250
# 10                  cao  0.044180
# 11             relaties  0.043177
# 12               heerma  0.040976
# 13              betaald  0.039084
# 14               pieter  0.038407
# 15        geconstateerd  0.035183
# 16             oneworld  0.032862
# 17           monumenten  0.032470
# 18              affairs  0.032031
# 19            inspectie  0.031959
# 20              erfgoed  0.031109
# 21             geldende  0.029699
# 22  arbeidsovereenkomst  0.029469
# 23               middel  0.029117
# 24       werkgeverschap  0.028808
# Cultuur en recreatie | Recreatie
#              feature     tfidf
# 0               fort  0.143649
# 1             oranje  0.129099
# 2            camping  0.117498
# 3            zundert  0.091824
# 4           campings  0.083839
# 5     vakantieparken  0.058111
# 6             horeca  0.056112
# 7           bewoning  0.053695
# 8           bewoners  0.052123
# 9           gemeente  0.052038
# 10        permanente  0.038008
# 11          strijdig  0.036970
# 12         horecawet  0.034049
# 13        ontruiming  0.031410
# 14    verblijfplaats  0.030930
# 15             drank  0.030496
# 16           contact  0.030318
# 17         permanent  0.030160
# 18        recreanten  0.028656
# 19      experimenten  0.028257
# 20         integrale  0.026758
# 21     burgemeesters  0.026375
# 22        verblijven  0.026164
# 23             wonen  0.026030
# 24  arbeidsmigranten  0.025757
# Cultuur en recreatie | Religie
#              feature     tfidf
# 0       islamitische  0.052168
# 1             moskee  0.043575
# 2           moskeeën  0.041907
# 3              graaf  0.041732
# 4               imam  0.038961
# 5            wilders  0.034531
# 6         religieuze  0.028778
# 7         christenen  0.023936
# 8             bontes  0.023461
# 9            moslims  0.023052
# 10          klaveren  0.021543
# 11             islam  0.021436
# 12              kerk  0.020606
# 13              neen  0.019653
# 14           utrecht  0.018472
# 15            arabië  0.018462
# 16          enschede  0.017905
# 17           koeweit  0.017733
# 18      organisaties  0.017638
# 19        mondelinge  0.016957
# 20            saoedi  0.016886
# 21           diyanet  0.015948
# 22            öztürk  0.015413
# 23  geweldspredikers  0.015162
# 24         omstreden  0.015077
# Cultuur en recreatie | Sport
#                feature     tfidf
# 0          matchfixing  0.077279
# 1                 knvb  0.071668
# 2             sporters  0.044282
# 3               dekken  0.040290
# 4              sporten  0.031124
# 5              voetbal  0.030997
# 6              spelers  0.029192
# 7                  nsf  0.028716
# 8                  noc  0.028716
# 9           sportclubs  0.022874
# 10         voetbalbond  0.022658
# 11  sportaccommodaties  0.022586
# 12               clubs  0.020909
# 13                club  0.020485
# 14         sportbonden  0.020336
# 15            veiliger  0.018916
# 16   geweldsincidenten  0.018595
# 17         wedstrijden  0.017997
# 18         voetballers  0.017324
# 19            gegevens  0.016318
# 20                fifa  0.015968
# 21            kinderen  0.015925
# 22   sportverenigingen  0.015752
# 23          praktijken  0.015614
# 24              geweld  0.014797
# Economie | Bouwnijverheid
#            feature     tfidf
# 0             bouw  0.087157
# 1            lakse  0.073129
# 2              nam  0.069490
# 3        dodelijke  0.064434
# 4            doden  0.064101
# 5           ronnes  0.062708
# 6    bewustwording  0.056201
# 7        conclusie  0.047831
# 8     experimenten  0.046207
# 9              ncg  0.045666
# 10       groningen  0.045512
# 11          blijft  0.045165
# 12       eindhoven  0.044832
# 13      aandringen  0.043956
# 14          bouwen  0.043528
# 15           faalt  0.039920
# 16  onvermijdelijk  0.038817
# 17        controle  0.038188
# 18           zones  0.036597
# 19      vormgeving  0.035477
# 20      aanbrengen  0.035074
# 21        aandacht  0.034151
# 22        afwijken  0.033913
# 23         eenmaal  0.033422
# 24      ongevallen  0.032873
# Economie | Handel
#                       feature     tfidf
# 0                        ttip  0.039354
# 1                      handel  0.035730
# 2                        ceta  0.027836
# 3   ontwikkelingssamenwerking  0.026212
# 4                          eu  0.021772
# 5                   bedrijven  0.021361
# 6                   producten  0.019922
# 7                       trade  0.018953
# 8                          vs  0.016130
# 9                        isds  0.015799
# 10                 mondelinge  0.014686
# 11                amerikaanse  0.013239
# 12               kinderarbeid  0.012590
# 13                     afrika  0.012366
# 14                     canada  0.011829
# 15           onderhandelingen  0.011797
# 16                 voorlopige  0.011781
# 17         vrijhandelsverdrag  0.011271
# 18                    verdrag  0.010741
# 19                    myanmar  0.010696
# 20                        wto  0.010556
# 21                 statiegeld  0.010423
# 22                 foundation  0.010277
# 23                     export  0.010257
# 24                    rusland  0.010235
# Economie | ICT
#              feature     tfidf
# 0                ict  0.041127
# 1               data  0.032780
# 2           internet  0.024118
# 3          bedrijven  0.023586
# 4   persoonsgegevens  0.022331
# 5           digitale  0.020946
# 6            mobiele  0.019189
# 7             hijink  0.019040
# 8           software  0.019031
# 9               raak  0.017741
# 10     cybersecurity  0.017177
# 11    kwetsbaarheden  0.016313
# 12             cyber  0.016270
# 13                it  0.016150
# 14          facebook  0.016036
# 15               fox  0.015309
# 16      ziekenhuizen  0.015067
# 17          gegevens  0.014880
# 18          security  0.014862
# 19          whatsapp  0.014828
# 20      aanbesteding  0.014466
# 21          websites  0.014363
# 22         consument  0.014131
# 23          overname  0.014117
# 24          systemen  0.013819
# Economie | Industrie
#                feature     tfidf
# 0               dupont  0.074738
# 1             ulenbelt  0.047196
# 2                  szw  0.041449
# 3             uitstoot  0.035325
# 4      tabaksindustrie  0.034050
# 5              fabriek  0.032338
# 6             chemours  0.032172
# 7         kinderarbeid  0.031316
# 8                 pfoa  0.029009
# 9                 stof  0.028732
# 10    arbeidsinspectie  0.027709
# 11               banen  0.026063
# 12                genx  0.025995
# 13           inspectie  0.023247
# 14             amnesty  0.022084
# 15              kampen  0.021452
# 16               congo  0.020554
# 17             giftige  0.019386
# 18             smaling  0.019277
# 19         smartphones  0.018968
# 20             verlies  0.018704
# 21                rivm  0.018702
# 22                auto  0.018364
# 23  werkomstandigheden  0.018103
# 24                 the  0.017810
# Economie | Markttoezicht
#            feature     tfidf
# 0              acm  0.024508
# 1            markt  0.021152
# 2        consument  0.019002
# 3            boete  0.018905
# 4        bedrijven  0.018702
# 5     concurrentie  0.016417
# 6       oneerlijke  0.015331
# 7          tickets  0.014870
# 8   incassobureaus  0.013653
# 9         unilever  0.013338
# 10       overnames  0.013139
# 11          hijink  0.013112
# 12     doorverkoop  0.012866
# 13           radar  0.012827
# 14      secundaire  0.012365
# 15       gesjoemel  0.012251
# 16         bedrijf  0.011717
# 17          boetes  0.011425
# 18  winstuitkering  0.011424
# 19         prijzen  0.011165
# 20            dure  0.010980
# 21       akzonobel  0.010864
# 22      industries  0.010699
# 23   overtredingen  0.010637
# 24           prijs  0.010352
# Economie | Ondernemen
#                 feature     tfidf
# 0                   zzp  0.058113
# 1           ondernemers  0.039624
# 2                   ers  0.037975
# 3       belastingdienst  0.030943
# 4                   mkb  0.027212
# 5        opdrachtgevers  0.022322
# 6         faillissement  0.021987
# 7                   dba  0.019813
# 8         zelfstandigen  0.018697
# 9             akzonobel  0.015921
# 10    modelovereenkomst  0.015320
# 11             overname  0.015304
# 12                  ppg  0.014934
# 13  modelovereenkomsten  0.014326
# 14            bedrijven  0.014027
# 15            doorstart  0.013084
# 16     ondernemingsraad  0.011489
# 17        ondernemingen  0.011461
# 18              klimaat  0.011249
# 19     dienstbetrekking  0.010483
# 20                   fd  0.010414
# 21          regelgeving  0.010353
# 22             unilever  0.010285
# 23                klein  0.010217
# 24               kleine  0.010106
# Economie | Organisatie en beleid
#               feature     tfidf
# 0              postnl  0.022907
# 1        supermarkten  0.020411
# 2           bedrijven  0.017401
# 3                 zzp  0.015968
# 4               pilot  0.015180
# 5       bedrijfsleven  0.015015
# 6                auto  0.013925
# 7       investeerders  0.013895
# 8          keurmerken  0.013714
# 9             çegerek  0.013036
# 10            dikkers  0.012845
# 11        registratie  0.012827
# 12          producten  0.012816
# 13               kiwa  0.012776
# 14           overname  0.012407
# 15             ruimte  0.011820
# 16                ets  0.011701
# 17        verwijderen  0.011404
# 18            bedrijf  0.011018
# 19             pakket  0.010996
# 20           openbare  0.010763
# 21         universele  0.010740
# 22                ncw  0.010698
# 23  lastenverlichting  0.010679
# 24                vno  0.010615
# Economie | Overige economische sectoren
#            feature     tfidf
# 0              nam  0.032763
# 1           banken  0.031664
# 2       gaswinning  0.017205
# 3        groningen  0.013917
# 4           postnl  0.013720
# 5           schade  0.013579
# 6          nijboer  0.013191
# 7       mondelinge  0.010969
# 8         rtvnoord  0.010824
# 9      accountants  0.010703
# 10             afm  0.010427
# 11            bank  0.010165
# 12    aardbevingen  0.009972
# 13       hypotheek  0.009785
# 14             ing  0.009478
# 15             abn  0.009327
# 16  mijnbouwschade  0.009217
# 17            amro  0.008719
# 18         schades  0.008349
# 19         klanten  0.007984
# 20        aardolie  0.007888
# 21       provincie  0.007821
# 22            sodm  0.007677
# 23             ncg  0.007582
# 24      vergunning  0.007418
# Economie | Toerisme
#              feature     tfidf
# 0          toeristen  0.114231
# 1                key  0.113896
# 2       bemiddelaars  0.101827
# 3            project  0.101804
# 4         huurhuizen  0.100723
# 5          wijziging  0.097598
# 6              vliet  0.092835
# 7   belastingheffing  0.089660
# 8           doorgang  0.088064
# 9          gevestigd  0.079373
# 10         amsterdam  0.076228
# 11       diersoorten  0.075904
# 12           planten  0.072489
# 13     gemeentelijke  0.066578
# 14       voorgenomen  0.065437
# 15          eilanden  0.065302
# 16          huurders  0.065279
# 17           besluit  0.063297
# 18           geneigd  0.060141
# 19          schetsen  0.059924
# 20              plan  0.059298
# 21            lusten  0.058484
# 22          effecten  0.057708
# 23        huursector  0.057597
# 24            onrust  0.057145
# Economie | Transport
#                   feature     tfidf
# 0              chauffeurs  0.063977
# 1               transport  0.039339
# 2                 schepen  0.035159
# 3                   spoor  0.030722
# 4                    kiwa  0.027007
# 5                engeland  0.025322
# 6             gevaarlijke  0.024174
# 7                 stoffen  0.023721
# 8                   loket  0.021068
# 9            vrachtwagens  0.020061
# 10           leefomgeving  0.018503
# 11              logistiek  0.018294
# 12                 rijden  0.018237
# 13                prorail  0.017518
# 14                helvert  0.016394
# 15                 diesel  0.015515
# 16                doelwit  0.015481
# 17              aanvragen  0.014461
# 18              afspraken  0.014398
# 19              belgische  0.014189
# 20         subsidiegelden  0.014045
# 21  vrachtwagenchauffeurs  0.013882
# 22             tolheffing  0.013754
# 23                 aanpak  0.013750
# 24                    fnv  0.013617
# Financiën | Begroting
#                   feature     tfidf
# 0              gesprekken  0.150591
# 1                 beloond  0.131349
# 2            terugbetaald  0.122239
# 3                 maarten  0.116887
# 4                  lening  0.113857
# 5            onderzoekers  0.113786
# 6               voortgang  0.111837
# 7              uitbetaald  0.110114
# 8                    sint  0.104859
# 9               doorbraak  0.102785
# 10            afwezigheid  0.100947
# 11                 bosman  0.094452
# 12                    rvo  0.086924
# 13            rijksdienst  0.084934
# 14  begrotingsbehandeling  0.083022
# 15                    625  0.082424
# 16            piadijkstra  0.074421
# 17            beschikbare  0.073760
# 18             herinneren  0.073030
# 19                  wonen  0.072739
# 20               volledig  0.072643
# 21             mondelinge  0.072518
# 22                 budget  0.071715
# 23                gevoerd  0.071106
# 24             betalingen  0.070130
# Financiën | Belasting
#                 feature     tfidf
# 0       belastingdienst  0.073905
# 1             toeslagen  0.025233
# 2               fiscale  0.021812
# 3   belastingplichtigen  0.020527
# 4   belastingontwijking  0.019453
# 5                fiscus  0.018561
# 6              vermogen  0.017435
# 7             belasting  0.017332
# 8      belastingverdrag  0.014441
# 9        multinationals  0.014344
# 10              rulings  0.014085
# 11           mondelinge  0.013140
# 12             aangifte  0.012761
# 13   belastingplichtige  0.012547
# 14              fiscaal  0.011426
# 15  belastingparadijzen  0.011400
# 16              heffing  0.011302
# 17                  ozb  0.011131
# 18              betalen  0.011020
# 19    belastingtelefoon  0.010771
# 20               belgië  0.010580
# 21                  btw  0.010390
# 22     belastingheffing  0.010243
# 23                  000  0.010094
# 24                  zzp  0.010061
# Financiën | Financieel toezicht
#           feature     tfidf
# 0             afm  0.059069
# 1          banken  0.052015
# 2             dnb  0.042533
# 3            bank  0.033097
# 4          regels  0.028158
# 5       beleggers  0.027886
# 6       kredieten  0.027712
# 7         nijboer  0.022235
# 8             ing  0.021388
# 9         markten  0.020270
# 10     boeterente  0.018969
# 11     hypotheken  0.018442
# 12            abn  0.018251
# 13       schulden  0.017981
# 14       beleggen  0.016353
# 15            ecb  0.016348
# 16       leidraad  0.016215
# 17             fd  0.015776
# 18          rente  0.015443
# 19    consumenten  0.015087
# 20      hypotheek  0.014944
# 21        krediet  0.014131
# 22       virtuele  0.013760
# 23       aandelen  0.013738
# 24  pensioenfonds  0.013600
# Financiën | Inkomensbeleid
#             feature     tfidf
# 0       topinkomens  0.062518
# 1           salaris  0.055092
# 2               wnt  0.054952
# 3        salarissen  0.038179
# 4       bestuurders  0.037086
# 5         normering  0.034865
# 6          verdient  0.032860
# 7    balkenendenorm  0.031293
# 8              norm  0.030406
# 9               top  0.030188
# 10   verpleeghuizen  0.027109
# 11    topsalarissen  0.025999
# 12         inkomens  0.024356
# 13       beloningen  0.024187
# 14            delta  0.023984
# 15       bestuurder  0.021670
# 16            boven  0.020838
# 17              111  0.019670
# 18         beloning  0.019369
# 19   commissarissen  0.019134
# 20          stijgen  0.018711
# 21        directeur  0.018456
# 22           topman  0.018399
# 23      directeuren  0.018047
# 24  toezichthouders  0.017918
# Financiën | Organisatie en beleid
#                    feature     tfidf
# 0                   banken  0.052911
# 1               kansspelen  0.045326
# 2       kansspelautoriteit  0.031010
# 3                     bank  0.028735
# 4                 rabobank  0.027018
# 5                hypotheek  0.018604
# 6                      ing  0.017910
# 7               hypotheken  0.017659
# 8               aanbieders  0.017637
# 9                   casino  0.016549
# 10                leningen  0.016465
# 11                     dnb  0.014640
# 12             beleggingen  0.014535
# 13                    amro  0.013866
# 14                 miljard  0.013736
# 15               subsidies  0.013634
# 16                     abn  0.013269
# 17                      fd  0.012987
# 18                     ecb  0.012893
# 19                 holland  0.011545
# 20  vennootschapsbelasting  0.011482
# 21                      eu  0.011273
# 22                     996  0.011251
# 23             stichtingen  0.011190
# 24            organisaties  0.011133
# Huisvesting | Bouwen en verbouwen
#                  feature     tfidf
# 0   aardbevingsbestendig  0.076560
# 1               woningen  0.066138
# 2                 bouwen  0.062763
# 3            bouwbesluit  0.052841
# 4                    npr  0.048709
# 5              groningen  0.041318
# 6                    nam  0.039972
# 7               bewoners  0.036535
# 8                 panden  0.033301
# 9                 cobouw  0.033095
# 10            woningbouw  0.032918
# 11         bouwprojecten  0.029954
# 12          aardbevingen  0.027600
# 13              gebouwen  0.027574
# 14            meerkosten  0.026450
# 15          vertragingen  0.026145
# 16           huisvesting  0.025810
# 17                woning  0.025000
# 18   vergunningverlening  0.022269
# 19             genegeerd  0.020908
# 20               gebouwd  0.020897
# 21         statushouders  0.020521
# 22         bouwbedrijven  0.019110
# 23             renovatie  0.019061
# 24             aangelegd  0.018910
# Huisvesting | Huren en verhuren
#               feature     tfidf
# 0            huurders  0.094410
# 1        huurwoningen  0.066770
# 2   woningcorporaties  0.063361
# 3                huur  0.041912
# 4           studenten  0.036324
# 5         verhuurders  0.033584
# 6            woningen  0.030922
# 7    woningcorporatie  0.029530
# 8          huurwoning  0.029224
# 9             huurder  0.029054
# 10      statushouders  0.027494
# 11        huurtoeslag  0.025513
# 12          huurprijs  0.023271
# 13               kops  0.021763
# 14          woningwet  0.021593
# 15              wonen  0.021307
# 16        corporaties  0.019516
# 17        huisvesting  0.019469
# 18         betaalbare  0.019064
# 19      huurcommissie  0.018559
# 20        rijksdienst  0.018498
# 21         verhuurder  0.017280
# 22        huurprijzen  0.017143
# 23       particuliere  0.017065
# 24               huis  0.016606
# Huisvesting | Kopen en verkopen
#                   feature     tfidf
# 0                starters  0.079319
# 1               hypotheek  0.077610
# 2                    huis  0.069596
# 3                  huizen  0.051839
# 4                senioren  0.049694
# 5            huizenkopers  0.047426
# 6             rijksdienst  0.045703
# 7             woningmarkt  0.045423
# 8                maatwerk  0.042313
# 9              hypotheken  0.041705
# 10                    ing  0.038158
# 11                  kopen  0.037734
# 12                   kops  0.037145
# 13                  markt  0.036535
# 14             mondelinge  0.035750
# 15                  wonen  0.035696
# 16                  linde  0.035675
# 17  hypotheekverstrekkers  0.035472
# 18               koolmees  0.034687
# 19                  greep  0.031094
# 20              groningse  0.026514
# 21              ombudsman  0.024470
# 22                eerlijk  0.023264
# 23                onnodig  0.022516
# 24                verliep  0.022455
# Huisvesting | Organisatie en beleid
#                feature     tfidf
# 0             woningen  0.055358
# 1                wonen  0.044120
# 2          woningmarkt  0.040073
# 3               ronnes  0.038548
# 4          rijksdienst  0.036373
# 5    woningcorporaties  0.035747
# 6           mondelinge  0.027892
# 7               woning  0.026795
# 8       gasaansluiting  0.025507
# 9         huurwoningen  0.024346
# 10        energielabel  0.022910
# 11            senioren  0.022887
# 12              tekort  0.019014
# 13       statushouders  0.018651
# 14            huurders  0.018538
# 15            gebouwen  0.018387
# 16             aardgas  0.017631
# 17  energievoorziening  0.017471
# 18              huizen  0.017153
# 19                anbo  0.016487
# 20             ouderen  0.015019
# 21            bewoners  0.014541
# 22                  ad  0.013603
# 23         aanjaagteam  0.013538
# 24                 cvw  0.013488
# Internationaal | Defensie
#         feature     tfidf
# 0      defensie  0.108984
# 1    militairen  0.048048
# 2     militaire  0.027579
# 3          navo  0.025235
# 4           jsf  0.021944
# 5    mondelinge  0.021205
# 6          mali  0.020298
# 7        popken  0.019696
# 8      militair  0.019385
# 9   krijgsmacht  0.019238
# 10        graag  0.017874
# 11       missie  0.017557
# 12   kernwapens  0.016626
# 13   luchtmacht  0.015574
# 14   toestellen  0.015402
# 15     commando  0.015117
# 16         mivd  0.014906
# 17      kazerne  0.014285
# 18        korps  0.014232
# 19       belhaj  0.014108
# 20    veteranen  0.013871
# 21        vuijk  0.013668
# 22    russische  0.013269
# 23  toelichting  0.012918
# 24         irak  0.012908
# Internationaal | Europese zaken
#                   feature     tfidf
# 0                      eu  0.068850
# 1               parlement  0.029224
# 2               commissie  0.028220
# 3                europees  0.027527
# 4             griekenland  0.026284
# 5                oekraïne  0.022108
# 6                    unie  0.021867
# 7           vluchtelingen  0.020294
# 8               lidstaten  0.018599
# 9                  brexit  0.018347
# 10                turkije  0.017757
# 11              hongarije  0.016623
# 12                maeijer  0.015643
# 13                  polen  0.015487
# 14                griekse  0.014827
# 15          antisemitisme  0.014799
# 16                 turkse  0.014450
# 17                juncker  0.014136
# 18                 europa  0.013386
# 19             referendum  0.012689
# 20          belastinggeld  0.012493
# 21                brussel  0.012280
# 22              migranten  0.012125
# 23              bulgarije  0.011200
# 24  vluchtelingenkinderen  0.011128
# Internationaal | Internationale samenwerking
#                       feature     tfidf
# 0                     turkije  0.026731
# 1                          vn  0.021799
# 2                  mondelinge  0.021564
# 3                   president  0.015876
# 4                          eu  0.015513
# 5                      turkse  0.015489
# 6                    kinderen  0.013435
# 7                 griekenland  0.013341
# 8                       syrië  0.011978
# 9                 afwezigheid  0.011679
# 10                     handel  0.011517
# 11                      noord  0.011072
# 12                     israël  0.010903
# 13                  sjoerdsma  0.010899
# 14                  koreaanse  0.010787
# 15                         vs  0.010658
# 16                       roon  0.010413
# 17                  corruptie  0.010233
# 18  ontwikkelingssamenwerking  0.010191
# 19                    amnesty  0.010123
# 20                       navo  0.010021
# 21                humanitaire  0.009664
# 22                      steun  0.009363
# 23                 referendum  0.009356
# 24                      korea  0.009243
# Internationaal | Militaire missies
#          feature     tfidf
# 0     militairen  0.119156
# 1        koerden  0.095069
# 2          syrië  0.085757
# 3         turkse  0.085049
# 4         missie  0.079765
# 5           irak  0.077118
# 6    afghanistan  0.062566
# 7      aanvallen  0.058134
# 8      eustatius  0.051521
# 9           mali  0.051496
# 10   explosieven  0.051102
# 11     karabulut  0.050791
# 12         trouw  0.050166
# 13  ambtsbericht  0.044274
# 14    mondelinge  0.043644
# 15         drone  0.043594
# 16     materieel  0.042255
# 17          sint  0.042010
# 18        drones  0.041955
# 19        doelen  0.041568
# 20    dreigement  0.040025
# 21      eenheden  0.039654
# 22            23  0.038375
# 23        eiland  0.037089
# 24     strijders  0.036506
# Internationaal | Ontwikkelingssamenwerking
#                       feature     tfidf
# 0   ontwikkelingssamenwerking  0.026941
# 1                 palestijnse  0.022450
# 2                    ethiopië  0.022210
# 3         ontwikkelingslanden  0.021265
# 4                    noodhulp  0.018699
# 5                        hulp  0.018267
# 6                     miljoen  0.017861
# 7                      dollar  0.017786
# 8                      handel  0.017525
# 9                          eu  0.016932
# 10                         vn  0.016352
# 11                    vrouwen  0.015616
# 12                   seksueel  0.015491
# 13                     afrika  0.015094
# 14              belastinggeld  0.014961
# 15                development  0.014010
# 16                     geweld  0.013882
# 17                  projecten  0.013841
# 18                   kinderen  0.013707
# 19                        ngo  0.013655
# 20                      leger  0.013617
# 21                        aid  0.013593
# 22              investeringen  0.013497
# 23              vluchtelingen  0.013317
# 24                         iv  0.012944
# Internationaal | Organisatie en beleid
#          feature     tfidf
# 0         turkse  0.034255
# 1        turkije  0.030403
# 2   autoriteiten  0.019038
# 3         israël  0.017785
# 4    israëlische  0.017434
# 5             vn  0.017128
# 6       regering  0.015794
# 7             eu  0.015179
# 8            the  0.014479
# 9    palestijnse  0.014321
# 10        bommel  0.013823
# 11    mondelinge  0.013721
# 12     president  0.012683
# 13       amnesty  0.011817
# 14     indonesië  0.011271
# 15            to  0.011142
# 16         syrië  0.010463
# 17  indonesische  0.010298
# 18   ambassadeur  0.010207
# 19     laarhoven  0.009104
# 20        bontes  0.009088
# 21     sjoerdsma  0.009017
# 22        thaise  0.009014
# 23      klaveren  0.008993
# 24      thailand  0.008917
# Internationaal | Reizen
#                     feature     tfidf
# 0                   turkije  0.109815
# 1                     korea  0.094279
# 2                 bulgaarse  0.085566
# 3                 bulgarije  0.085127
# 4                     noord  0.069690
# 5                 toeristen  0.059666
# 6                terrorisme  0.059630
# 7                 koreaanse  0.055951
# 8              gearresteerd  0.054212
# 9                   amerika  0.051643
# 10               monitoring  0.051140
# 11               spanningen  0.050471
# 12                 militair  0.049763
# 13              uitlatingen  0.049428
# 14                 betreden  0.048172
# 15                studenten  0.046039
# 16              gebeurtenis  0.045954
# 17                corruptie  0.044765
# 18                     2011  0.042523
# 19              intimidatie  0.042390
# 20              rotterdamse  0.042341
# 21                 betaling  0.040987
# 22  mensenrechtenactivisten  0.040205
# 23                geweigerd  0.039887
# 24                  hieruit  0.039258
# Landbouw | Dieren
#              feature     tfidf
# 0             dieren  0.064690
# 1               nvwa  0.029950
# 2        veehouderij  0.023476
# 3    pluimveehouders  0.020631
# 4               stal  0.019594
# 5            varkens  0.019181
# 6             natuur  0.018433
# 7   voedselkwaliteit  0.018335
# 8           landbouw  0.018045
# 9          boerderij  0.017539
# 10              pvdd  0.015785
# 11            verbod  0.014966
# 12           stallen  0.014755
# 13             doden  0.014648
# 14     dierenwelzijn  0.014261
# 15              dier  0.013987
# 16            koorts  0.013712
# 17           paarden  0.013178
# 18        wassenberg  0.013142
# 19            koeien  0.012812
# 20            wakker  0.012540
# 21  veronderstelling  0.012452
# 22            kippen  0.012240
# 23     overtredingen  0.012168
# 24            dekken  0.012016
# Landbouw | Organisatie en beleid
#                 feature     tfidf
# 0              landbouw  0.037077
# 1                boeren  0.032394
# 2                   rvo  0.027303
# 3             dijkgraaf  0.027077
# 4             glyfosaat  0.024001
# 5             akkerbouw  0.023335
# 6                natuur  0.023329
# 7                  mest  0.023151
# 8      voedselkwaliteit  0.022736
# 9             boerderij  0.021237
# 10              fosfaat  0.020968
# 11  professionalisering  0.019322
# 12          ondernemend  0.019281
# 13              bonaire  0.019041
# 14                  sgp  0.018905
# 15              lodders  0.018757
# 16          nieuweoogst  0.018371
# 17            toelating  0.017154
# 18               franse  0.016536
# 19            schroeven  0.015890
# 20                losse  0.015104
# 21             subsidie  0.014893
# 22                  lto  0.014668
# 23           verbindend  0.014609
# 24           mondelinge  0.014574
# Landbouw | Planten
#                       feature     tfidf
# 0   gewasbeschermingsmiddelen  0.077212
# 1                  drugsafval  0.074122
# 2                      resten  0.061735
# 3                         xtc  0.057221
# 4                     planten  0.051054
# 5                        nvwa  0.041495
# 6                         858  0.039755
# 7                   toelating  0.039715
# 8                   productie  0.036485
# 9                    gevonden  0.035030
# 10                  glyfosaat  0.034670
# 11                     verbod  0.031844
# 12                   opruimen  0.030136
# 13                 medicinale  0.029495
# 14               voedselketen  0.029402
# 15                 technieken  0.029233
# 16           oppervlaktewater  0.027922
# 17                  akkerbouw  0.027357
# 18              professioneel  0.026173
# 19                       lang  0.026049
# 20                   biociden  0.025529
# 21              rechtstreekse  0.025160
# 22                 genetische  0.024969
# 23             ontwerpbesluit  0.024922
# 24                     vondst  0.024726
# Landbouw | Voedselkwaliteit
#                  feature     tfidf
# 0                   nvwa  0.116726
# 1                voedsel  0.087097
# 2                 eieren  0.064949
# 3               fipronil  0.055039
# 4                  fruit  0.051097
# 5               gewassen  0.047018
# 6   bestrijdingsmiddelen  0.043591
# 7               ouwehand  0.042757
# 8                 boeren  0.040205
# 9              controles  0.039902
# 10       warenautoriteit  0.037018
# 11            bevestigen  0.036080
# 12                   zes  0.033971
# 13              illegale  0.033477
# 14                 ander  0.030948
# 15                geurts  0.030786
# 16                  keer  0.030034
# 17           consumenten  0.029412
# 18             producten  0.029247
# 19              gebruikt  0.028897
# 20                 vlees  0.028844
# 21                 inzet  0.027211
# 22            toorenburg  0.027015
# 23                gebied  0.026367
# 24          supermarkten  0.026349
# Migratie en integratie | Emigratie
#            feature     tfidf
# 0              iom  0.213257
# 1          syriërs  0.192032
# 2        terugkeer  0.186419
# 3      vrijwillige  0.167726
# 4            syrië  0.158326
# 5    vluchtelingen  0.134835
# 6        groeiende  0.121584
# 7       begeleiden  0.110259
# 8      afghanistan  0.107998
# 9            terug  0.105807
# 10          veilig  0.103526
# 11           keren  0.102730
# 12            huis  0.096609
# 13          genoeg  0.091141
# 14          azmani  0.090859
# 15          willen  0.087035
# 16            land  0.086405
# 17           belet  0.083926
# 18  daaropvolgende  0.080771
# 19       afghaanse  0.080005
# 20    voorbehouden  0.079893
# 21           groep  0.077974
# 22             wil  0.076393
# 23       obstakels  0.075169
# 24     verhinderen  0.075169
# Migratie en integratie | Immigratie
#                 feature     tfidf
# 0          asielzoekers  0.070426
# 1         vluchtelingen  0.039788
# 2                   coa  0.033129
# 3                opvang  0.026677
# 4         vreemdelingen  0.026580
# 5                   ind  0.026262
# 6             migranten  0.022665
# 7                   azc  0.020413
# 8           asielzoeker  0.019698
# 9         statushouders  0.018460
# 10           mondelinge  0.017775
# 11             kinderen  0.016697
# 12  verblijfsvergunning  0.016209
# 13           gesthuizen  0.015173
# 14     gezinshereniging  0.014919
# 15  naturalisatiedienst  0.013821
# 16               orgaan  0.013746
# 17              fritsma  0.013687
# 18   asielzoekerscentra  0.013652
# 19           immigratie  0.013542
# 20          inburgering  0.012314
# 21  asielzoekerscentrum  0.012052
# 22          vluchteling  0.011498
# 23             uitgezet  0.011320
# 24                graaf  0.010694
# Migratie en integratie | Integratie
#           feature     tfidf
# 0     inburgering  0.083704
# 1      integratie  0.082112
# 2          turkse  0.037499
# 3           turks  0.032767
# 4   statushouders  0.032266
# 5      segregatie  0.031289
# 6      huwelijken  0.028479
# 7     allochtonen  0.027295
# 8        moskeeën  0.026900
# 9     samenleving  0.025871
# 10     ziekenhuis  0.024193
# 11     huwelijkse  0.023954
# 12    marokkaanse  0.023772
# 13          klein  0.023546
# 14   participatie  0.023135
# 15         regime  0.022888
# 16  gevangenschap  0.022320
# 17       huwelijk  0.021644
# 18    vrouwelijke  0.021613
# 19   houdbaarheid  0.021603
# 20  vluchtelingen  0.021396
# 21       bijstand  0.021340
# 22       aannames  0.021330
# 23        mislukt  0.020799
# 24     mannelijke  0.020319
# Migratie en integratie | Nederlanderschap
#               feature     tfidf
# 0       nationaliteit  0.220807
# 1             armenië  0.141055
# 2            armeense  0.132989
# 3             syriërs  0.114513
# 4         amsterdamse  0.107247
# 5                 112  0.100972
# 6             geboren  0.099903
# 7                géén  0.093921
# 8            paspoort  0.088073
# 9              arrest  0.087872
# 10           kinderen  0.083650
# 11          procedure  0.082240
# 12               vast  0.081196
# 13           gestuurd  0.077800
# 14              asiel  0.070778
# 15          ombudsman  0.070145
# 16         meegewogen  0.069724
# 17   nederlanderschap  0.065141
# 18                133  0.064869
# 19  kinderombudsvrouw  0.063773
# 20          verblijft  0.062807
# 21              nooit  0.062358
# 22        groothuizen  0.061255
# 23             ouders  0.060775
# 24          uitzetten  0.056908
# Migratie en integratie | Organisatie en beleid
#                 feature     tfidf
# 0          asielzoekers  0.061867
# 1              eritrese  0.051588
# 2   verblijfsvergunning  0.037161
# 3         vluchtelingen  0.036265
# 4                douane  0.029797
# 5               fritsma  0.028356
# 6                   azc  0.027461
# 7            eritreeërs  0.027456
# 8               turkije  0.027292
# 9             migranten  0.023639
# 10             uitgezet  0.023428
# 11               opvang  0.023405
# 12              eritrea  0.022267
# 13               regime  0.022232
# 14                  coa  0.022068
# 15             klaveren  0.021380
# 16            uitzetten  0.020115
# 17               bontes  0.020031
# 18          intimidatie  0.019386
# 19              vrouwen  0.018776
# 20             dijkhoff  0.017769
# 21                 lhbt  0.017300
# 22                  hen  0.017146
# 23                  ind  0.016843
# 24           immigratie  0.016780
# Migratie en integratie | Tijdelijk verblijf
#                  feature     tfidf
# 0                    coa  0.136729
# 1           asielzoekers  0.088988
# 2               aangifte  0.087043
# 3         geregistreerde  0.082864
# 4         opvanglocaties  0.080078
# 5    onderzoekscommissie  0.078762
# 6               gevallen  0.075238
# 7              materiële  0.072322
# 8               herkomst  0.069609
# 9             vervolging  0.069163
# 10              agressie  0.066370
# 11                gelukt  0.066002
# 12             ingesteld  0.065582
# 13               dakloze  0.062355
# 14            harderwijk  0.062355
# 15       klaarblijkelijk  0.061425
# 16              personen  0.057348
# 17                 woont  0.057311
# 18            incidenten  0.055537
# 19   gezondheidsklachten  0.055400
# 20                vorige  0.052521
# 21  bijstandsuitkeringen  0.052113
# 22               patiënt  0.051380
# 23             meldingen  0.051112
# 24            ziekenhuis  0.051039
# Natuur en milieu | Afval
#              feature     tfidf
# 0              afval  0.074287
# 1         drugsafval  0.047213
# 2           opruimen  0.035882
# 3            cegerek  0.029607
# 4          dumpingen  0.026595
# 5             dumpen  0.025791
# 6            plastic  0.025288
# 7       verpakkingen  0.025134
# 8          recycling  0.022607
# 9         gelderland  0.021213
# 10  raamovereenkomst  0.021109
# 11          verhalen  0.020365
# 12         provincie  0.019989
# 13       producenten  0.019601
# 14     remcodijkstra  0.019157
# 15    drugsdumpingen  0.018856
# 16        afvalwater  0.018817
# 17         telefoons  0.018694
# 18     kolencentrale  0.018535
# 19           schepen  0.018290
# 20            acties  0.017832
# 21        inzameling  0.017787
# 22        verwerking  0.017627
# 23           brabant  0.016593
# 24               nam  0.016307
# Natuur en milieu | Bodem
#          feature     tfidf
# 0            nam  0.101401
# 1           sodm  0.045302
# 2      groningen  0.045082
# 3     gaswinning  0.040283
# 4          bodem  0.035350
# 5      akzonobel  0.031866
# 6        lekkage  0.030302
# 7       lekkages  0.029257
# 8      vervuilde  0.027318
# 9      provincie  0.025942
# 10    vervuiling  0.023760
# 11   afhandeling  0.022587
# 12     beckerman  0.021534
# 13    grondwater  0.021359
# 14        kabels  0.020871
# 15  winningsplan  0.020051
# 16      gewonnen  0.019773
# 17    aardbeving  0.019399
# 18    groningers  0.019312
# 19          dvhn  0.018038
# 20           gas  0.017542
# 21      augustus  0.017039
# 22        schade  0.016770
# 23      tubantia  0.016428
# 24   zoutwinning  0.016415
# Natuur en milieu | Energie
#              feature     tfidf
# 0            energie  0.040613
# 1         windmolens  0.030483
# 2     kolencentrales  0.024905
# 3       kerncentrale  0.024554
# 4           duurzame  0.023365
# 5     energieakkoord  0.022627
# 6        windenergie  0.022184
# 7                gas  0.021955
# 8                sde  0.021823
# 9           biomassa  0.019406
# 10      windturbines  0.019224
# 11             meter  0.016926
# 12              wind  0.016838
# 13            tennet  0.016446
# 14          windpark  0.015749
# 15            slimme  0.015073
# 16          subsidie  0.013762
# 17       kernreactor  0.013548
# 18      milieubeheer  0.013432
# 19            aanleg  0.013320
# 20          borssele  0.013274
# 21          tongeren  0.013223
# 22        windparken  0.013082
# 23      exploitanten  0.012941
# 24  energieproductie  0.012905
# Natuur en milieu | Geluid
#             feature     tfidf
# 0   geluidsoverlast  0.163592
# 1          schiphol  0.082413
# 2     geluidshinder  0.080931
# 3   rijkswaterstaat  0.077954
# 4   geluidsschermen  0.069553
# 5          overlast  0.067393
# 6             langs  0.054448
# 7              brug  0.053438
# 8        luchthaven  0.045665
# 9               oss  0.044765
# 10       waterstaat  0.043769
# 11              rws  0.038745
# 12      vliegtuigen  0.032358
# 13         gemeente  0.027861
# 14       rijkswegen  0.027664
# 15             dorp  0.027630
# 16           dorpen  0.027008
# 17            tracé  0.026617
# 18             type  0.026564
# 19       omwonenden  0.026551
# 20        rtlnieuws  0.026483
# 21             sint  0.026344
# 22          urgente  0.025821
# 23           klacht  0.025799
# 24         fijnstof  0.024128
# Natuur en milieu | Lucht
#              feature     tfidf
# 0     luchtkwaliteit  0.072235
# ...
# 18     vervoerders  0.019137
# 19    vrachtwagens  0.017443
# 20          rijden  0.017340
# 21     politiebond  0.017286
# 22           trein  0.016921
# 23         helvert  0.016384
# 24       provincie  0.016159
# Verkeer | Spoor
#            feature     tfidf
# 0               ns  0.134394
# 1          prorail  0.093706
# 2            spoor  0.061889
# 3          treinen  0.057511
# 4          station  0.056506
# 5            trein  0.053857
# 6        reizigers  0.049398
# 7   dienstregeling  0.032323
# 8        intercity  0.032156
# 9         stations  0.023590
# 10      waterstaat  0.022866
# 11      prestaties  0.021165
# 12          rijden  0.020778
# 13              ic  0.019773
# 14        randstad  0.019164
# 15            boer  0.018848
# 16     machinisten  0.018613
# 17       overwegen  0.017943
# 18      realisatie  0.017507
# 19     recreatieve  0.016918
# 20        reiziger  0.016005
# 21            zuid  0.015825
# 22        hoogland  0.015444
# 23         traject  0.014851
# 24       concessie  0.013953
# Verkeer | Water
#          feature     tfidf
# 0    binnenvaart  0.077278
# 1        schepen  0.065714
# 2     zeeschepen  0.049272
# 3         jacobi  0.038928
# 4       noordzee  0.035427
# 5          schip  0.031782
# 6          haven  0.029694
# 7          water  0.028124
# 8            zee  0.026407
# 9        zeeland  0.024329
# 10      medische  0.022240
# 11  marktwerking  0.020661
# 12           409  0.020090
# 13           gps  0.019137
# 14          boer  0.019055
# 15        vermue  0.018344
# 16  spoedeisende  0.018271
# 17   certificaat  0.018199
# 18     kustwacht  0.018062
# 19        belhaj  0.018050
# 20       beerput  0.017697
# 21           wal  0.017632
# 22   rotterdamse  0.017270
# 23    investeren  0.017061
# 24        havens  0.016501
# Verkeer | Weg
#                feature     tfidf
# 0   verkeersveiligheid  0.050894
# 1           ongelukken  0.030593
# 2                  cbr  0.028263
# 3              verkeer  0.026799
# 4      rijkswaterstaat  0.023787
# 5                wegen  0.022912
# 6         doorstroming  0.020074
# 7             filedruk  0.019901
# 8         vrachtwagens  0.019766
# 9             hoogland  0.017783
# 10      automobilisten  0.017467
# 11                brug  0.017385
# 12           provincie  0.016486
# 13          rijstroken  0.015533
# 14          tolheffing  0.015121
# 15           storingen  0.015099
# 16       vrachtverkeer  0.014560
# 17                 rdw  0.013982
# 18              visser  0.013472
# 19      bereikbaarheid  0.013444
# 20              belhaj  0.013430
# 21                auto  0.013406
# 22   verkeersregelaars  0.013159
# 23             helvert  0.012731
# 24           oplossing  0.012575
# Werk | Arbeidsomstandigheden
#                   feature     tfidf
# 0              werknemers  0.061727
# 1                     szw  0.050189
# 2               inspectie  0.034733
# 3              misstanden  0.031886
# 4   arbeidsomstandigheden  0.031730
# 5                     fnv  0.025927
# 6             medewerkers  0.023809
# 7                    loon  0.023442
# 8                    werk  0.022625
# 9               werknemer  0.019815
# 10               kerstens  0.019279
# 11            beveiligers  0.018849
# 12    gezondheidsklachten  0.018243
# 13         longontsteking  0.018087
# 14                spreken  0.017577
# 15              controles  0.017435
# 16                 albert  0.017189
# 17       ondernemingsraad  0.016948
# 18         onderzoeksraad  0.016704
# 19          ziekteverzuim  0.016611
# 20                 özütok  0.016032
# 21                 dienst  0.015861
# 22                brouwer  0.015420
# 23             ongevallen  0.015394
# 24                   bouw  0.015390
# Werk | Arbeidsvoorwaarden
#                     feature     tfidf
# 0                       cao  0.052474
# 1                  regeling  0.038565
# 2                    verlof  0.033517
# 3                  pensioen  0.031958
# 4                mondelinge  0.031252
# 5             pensioenfonds  0.029983
# 6                 weyenberg  0.029713
# 7                   moeders  0.029535
# 8             zelfstandigen  0.029514
# 9                       uwv  0.029329
# 10               verbindend  0.025930
# 11                     werk  0.025225
# 12                 praktijk  0.024657
# 13                  wiersma  0.022859
# 14           werkgeverschap  0.022653
# 15                draagvlak  0.021160
# 16             constructies  0.021077
# 17              uitbreiding  0.020954
# 18                 deelname  0.020711
# 19                werknemer  0.020470
# 20  werknemersverzekeringen  0.020390
# 21                   langer  0.019702
# 22                  vergeet  0.019459
# 23                      zzp  0.019379
# 24               werknemers  0.019292
# Werk | Levensloop
#                  feature     tfidf
# 0   arbeidsinkomensquote  0.343748
# 1              werkenden  0.249799
# 2                kleiner  0.236404
# 3               verhogen  0.227239
# 4                   1995  0.212978
# 5                aandeel  0.201313
# 6                  lonen  0.184950
# 7                invloed  0.183014
# 8                   neen  0.170289
# 9                 niveau  0.155397
# 10                 lager  0.153604
# 11             bedrijven  0.140509
# 12           voorstellen  0.128164
# 13           prinsjesdag  0.127544
# 14            werknemers  0.126801
# 15        winstbelasting  0.125788
# 16                  flex  0.124200
# 17          verdubbeling  0.120181
# 18                column  0.117955
# 19              verdiend  0.111198
# 20               oefenen  0.108044
# 21             indirecte  0.108044
# 22       aantrekkelijker  0.107479
# 23               duurder  0.105890
# 24                   dft  0.103984
# Werk | Ontslag
#             feature     tfidf
# 0         doorstart  0.088582
# 1           hengelo  0.079864
# 2            oudere  0.061813
# 3              dupe  0.060948
# 4         ontslagen  0.060647
# 5             banen  0.053573
# 6        werknemers  0.053545
# 7          managers  0.048105
# 8         vestiging  0.046546
# 9     faillissement  0.043127
# 10               ns  0.042744
# 11         augustus  0.041409
# 12          curator  0.039526
# 13         kerstens  0.035125
# 14         behouden  0.033358
# 15             krol  0.032920
# 16          sluiten  0.030932
# 17        curatoren  0.030024
# 18  uitzendkrachten  0.028738
# 19      medewerkers  0.028414
# 20           hijink  0.028002
# 21   werkgeverschap  0.027916
# 22          klimaat  0.027765
# 23        duitsland  0.026539
# 24              170  0.026236
# Werk | Organisatie en beleid
#                feature     tfidf
# 0           werkgevers  0.037545
# 1           werknemers  0.031237
# 2                  cao  0.030289
# 3                  szw  0.027206
# 4               werken  0.024886
# 5       uitzendbureaus  0.022275
# 6                  mkb  0.021050
# 7        discrimineert  0.019180
# 8    onafhankelijkheid  0.018743
# 9         solliciteren  0.018613
# 10        deurwaarders  0.018391
# 11       discrimineren  0.018097
# 12       discriminatie  0.017931
# 13            middelen  0.016854
# 14                 fnv  0.016763
# 15                heer  0.015877
# 16               yücel  0.015732
# 17              zomaar  0.015573
# 18                baan  0.015484
# 19                 uwv  0.015371
# 20      incassobureaus  0.015328
# 21           inspectie  0.015174
# 22                 scp  0.014981
# 23             inkomen  0.014813
# 24  arbeidsvoorwaarden  0.014698
# Werk | Werkgelegenheid
#           feature     tfidf
# 0           banen  0.058023
# 1     verdringing  0.044856
# 2      werkgevers  0.044770
# 3            baan  0.038888
# 4            werk  0.037027
# 5    arbeidsmarkt  0.034687
# 6             ers  0.032105
# 7   werkzoekenden  0.031421
# 8      grensregio  0.031245
# 9        kerstens  0.029300
# 10            uwv  0.027906
# 11         arbeid  0.027223
# 12      barrières  0.026619
# 13       betaalde  0.026473
# 14  zelfstandigen  0.025917
# 15     contracten  0.024536
# 16     werknemers  0.023933
# 17         schijn  0.023637
# 18     loondienst  0.023202
# 19      duitsland  0.022846
# 20         schiet  0.022345
# 21  lerarentekort  0.022306
# 22         weinig  0.021225
# 23     mondelinge  0.020849
# 24            zzp  0.020822
# Zorg en gezondheid | Ethiek
#                 feature     tfidf
# 0            euthanasie  0.057008
# 1   toetsingscommissies  0.031077
# 2                   igz  0.027719
# 3            coöperatie  0.026514
# 4              medische  0.026212
# 5                staaij  0.023659
# 6               medisch  0.023411
# 7               sexting  0.021481
# 8               patiënt  0.021267
# 9                   sgp  0.020370
# 10            patiënten  0.020033
# 11                 arts  0.018575
# 12           zelfdoding  0.018236
# 13        euthanasiewet  0.018199
# 14          verstrekken  0.017329
# 15               artsen  0.016956
# 16             gegevens  0.016742
# 17           calamiteit  0.016729
# 18       wilsverklaring  0.015357
# 19          toestemming  0.015338
# 20         nabestaanden  0.014364
# 21            naaktfoto  0.013659
# 22              laatste  0.013529
# 23            regionale  0.013432
# 24              reclame  0.013413
# Zorg en gezondheid | Geneesmiddelen en medische hulpmiddelen
#               feature     tfidf
# 0      geneesmiddelen  0.056776
# 1          medicijnen  0.054269
# 2           patiënten  0.035596
# 3      farmaceutische  0.034293
# 4          apothekers  0.033244
# 5           fabrikant  0.030281
# 6        geneesmiddel  0.028635
# 7            medicijn  0.026299
# 8           medicatie  0.022264
# 9            medische  0.022033
# 10          gerbrands  0.021580
# 11      voorschrijven  0.021268
# 12             thyrax  0.021236
# 13       hulpmiddelen  0.020671
# 14        beschikbaar  0.020064
# 15          productie  0.017519
# 16       bijwerkingen  0.015263
# 17                igz  0.015147
# 18  geneesmiddelenwet  0.014997
# 19        behandeling  0.014671
# 20         vergoeding  0.014431
# 21          farmaceut  0.014125
# 22        antibiotica  0.014084
# 23     antidepressiva  0.013975
# 24          industrie  0.013877
# Zorg en gezondheid | Gezondheidsrisico's
#                  feature     tfidf
# 0               huurders  0.073172
# 1              opknappen  0.066433
# 2          achterstallig  0.064955
# 3      gezondheidsrisico  0.064030
# 4              onderhoud  0.058036
# 5       woningcorporatie  0.055054
# 6                 woning  0.053776
# 7               woningen  0.051492
# 8                  grond  0.042674
# 9                 waarop  0.042013
# 10                  doet  0.041056
# 11              uitspaak  0.040068
# 12        schimmelhuizen  0.040068
# 13              schimmel  0.039983
# 14      schimmelwoningen  0.039893
# 15          beschimmelde  0.039893
# 16     schimmelproblemen  0.039722
# 17          woonsituatie  0.039722
# 18         voortvarender  0.039722
# 19                 vocht  0.039394
# 20               toekent  0.039237
# 21         huurverlaging  0.039237
# 22  schimmelproblematiek  0.039143
# 23                gezond  0.039012
# 24             ongezonde  0.038932
# Zorg en gezondheid | Jongeren
#                      feature     tfidf
# 0                   kinderen  0.071538
# 1                  jeugdzorg  0.054016
# 2                   jongeren  0.041911
# 3                      jeugd  0.041224
# 4             kindertelefoon  0.028721
# 5                  jeugdhulp  0.028519
# 6                   jeugdwet  0.027039
# 7                        akj  0.022020
# 8               wachtlijsten  0.019560
# 9            decentralisatie  0.019378
# 10                psychische  0.019116
# 11                    ouders  0.018932
# 12                   kooiman  0.018726
# 13                      hulp  0.018376
# 14                  gesloten  0.017476
# 15              instellingen  0.017010
# 16                       ggz  0.016834
# 17                      kind  0.016745
# 18  stelselverantwoordelijke  0.016211
# 19                  gegevens  0.016186
# 20                 geplaatst  0.015447
# 21                  gemeente  0.015434
# 22                       vng  0.015154
# 23                  bergkamp  0.014466
# 24              voortbestaan  0.013337
# Zorg en gezondheid | Organisatie en beleid
#              feature     tfidf
# 0         ziekenhuis  0.021283
# 1                igz  0.016769
# 2       ziekenhuizen  0.016765
# 3          patiënten  0.015457
# 4           cliënten  0.014962
# 5   zorgverzekeraars  0.014631
# 6                ggz  0.012969
# 7                pgb  0.012717
# 8                wmo  0.012632
# 9                nza  0.011904
# 10              neen  0.011312
# 11  zorginstellingen  0.011245
# 12          medische  0.009934
# 13           patiënt  0.009917
# 14    zorginstelling  0.009486
# 15        huisartsen  0.009427
# 16     zorgverleners  0.008581
# 17           bestuur  0.008546
# 18   zorgverzekeraar  0.008305
# 19             agema  0.008189
# 20      spoedeisende  0.008071
# 21          oordeelt  0.007846
# 22              hulp  0.007802
# 23           medisch  0.007638
# 24           ouderen  0.007606
# Zorg en gezondheid | Ouderen
#                  feature     tfidf
# 0                ouderen  0.143797
# 1                  agema  0.037960
# 2                 oudere  0.034232
# 3         huishoudelijke  0.033380
# 4           ziekenhuizen  0.031514
# 5               bewoners  0.029361
# 6                   krol  0.029276
# 7           verpleeghuis  0.028932
# 8      verzorgingshuizen  0.028601
# 9               cliënten  0.025226
# 10            ziekenhuis  0.024988
# 11           ouderenzorg  0.024458
# 12                moeder  0.024389
# 13                50plus  0.024217
# 14             overlijdt  0.024109
# 15  thuiszorgmedewerkers  0.023267
# 16               notaris  0.022679
# 17              dementie  0.022170
# 18          hoogbejaarde  0.021853
# 19                 thuis  0.021585
# 20                  hulp  0.020718
# 21                   102  0.020102
# 22             thuiszorg  0.019571
# 23             verhullen  0.018937
# 24               patiënt  0.018526
# Zorg en gezondheid | Verzekeringen
#              feature     tfidf
# 0   zorgverzekeraars  0.096900
# 1    zorgverzekeraar  0.063686
# 2        verzekerden  0.052456
# 3            vergoed  0.041929
# 4                nza  0.034055
# 5       verzekeraars  0.033792
# 6             achmea  0.023272
# 7                ggz  0.022878
# 8                vgz  0.022391
# 9       gedeclareerd  0.022353
# 10             eigen  0.021862
# 11        declareren  0.020720
# 12      ziekenhuizen  0.020349
# 13    wijkverpleging  0.019909
# 14           miljoen  0.019480
# 15         patiënten  0.018930
# 16          zilveren  0.018402
# 17             kruis  0.017780
# 18        ziekenhuis  0.017619
# 19            gerven  0.017416
# 20        zorgplicht  0.017168
# 21           leijten  0.017155
# 22        zorgkosten  0.017088
# 23       behandeling  0.016984
# 24         gerbrands  0.016590
# Zorg en gezondheid | Voeding
#              feature     tfidf
# 0               cost  0.105099
# 1               food  0.098630
# 2   maatschappelijke  0.077262
# 3                 uk  0.076983
# 4            voeding  0.073014
# 5         wageningen  0.061963
# 6       ondervoeding  0.060121
# 7                the  0.056782
# 8          preventie  0.054757
# 9          verlengde  0.054442
# 10  voedselkwaliteit  0.054288
# 11           voedsel  0.052561
# 12     onderbetaling  0.045555
# 13                ur  0.044927
# 14              true  0.044360
# 15       convenanten  0.043008
# 16           stoffen  0.041614
# 17              nvwa  0.040674
# 18          landbouw  0.038293
# 19            natuur  0.037293
# 20      gepubliceerd  0.036807
# 21     afzonderlijke  0.036164
# 22          beweging  0.035716
# 23      gevalideerde  0.035148
# 24            boeren  0.034889
# Zorg en gezondheid | Ziekten en behandelingen
#             feature     tfidf
# 0         patiënten  0.053258
# 1           vrouwen  0.049409
# 2               igz  0.036606
# 3          medische  0.033891
# 4   gezondheidszorg  0.033409
# 5      ziekenhuizen  0.031513
# 6           abortus  0.030723
# 7         overleden  0.029399
# 8         diagnoses  0.026734
# 9        abortussen  0.025858
# 10          methode  0.025798
# 11     zwangerschap  0.025383
# 12          ziekten  0.023673
# 13           kennis  0.022945
# 14          ierland  0.021810
# 15       ziekenhuis  0.021644
# 16           ziekte  0.021308
# 17        inspectie  0.020454
# 18      verschillen  0.020166
# 19       wageningse  0.019981
# 20        operaties  0.019338
# 21             hart  0.018041
# 22       onbedoelde  0.017733
# 23           muggen  0.017613
# 24     onderzoekers  0.017286

# %%
# Out:
# [0]
